# %% [markdown]
# ## Reconhecimento de Espécies Florestais por Visão Computacional em Ambientes com Recursos Computacionais Limitados

# %% [markdown]
# ### Desenvolvido por
#
# **André Rizzo**
# Cientista de Dados Sênior | Estatístico | MBA em IA e Big Data (USP)
# andrerizzo@hotmail.com
# http://www.linkedin.com/in/andrerizzo1

# %% [markdown]
# ### 1. Preparação do Ambiente

# %% [markdown]
# #### 1.1. Instala bibliotecas

# %%
# %pip install mlflow dagshub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 101.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 119.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.1/329.1 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 14.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 140.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 11.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# #### 1.2. Baixa arquivos com os scripts

# %%
import os
import zipfile
import shutil

# 1. Baixar o ZIP do GitHub
ZIP_URL = "https://github.com/andrerizzo/Reconhecimento_de_Especies_Florestais/archive/refs/heads/master.zip"
ZIPFILE = "/content/Reconhecimento_de_Especies_Florestais.zip"

print("Baixando o dataset...")
# !wget "$ZIP_URL" -O "$ZIPFILE"

# 2. Extrair o conteúdo
extract_path = "/content"

print("Extraindo arquivos...")
with zipfile.ZipFile(ZIPFILE, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# 3. Mover os arquivos da subpasta para /content
extracted_folder = os.path.join(extract_path, "Reconhecimento_de_Especies_Florestais-master")

print("Movendo arquivos para a raiz do Colab...")
for item in os.listdir(extracted_folder):
    shutil.move(os.path.join(extracted_folder, item), extract_path)

# 4. Limpar: remover pasta intermediária e ZIP
print("Limpando arquivos temporários...")
shutil.rmtree(extracted_folder)
os.remove(ZIPFILE)

print("Processo finalizado com sucesso!")
# Out:
# Baixando o dataset...
# --2025-10-20 18:09:43--  https://github.com/andrerizzo/Reconhecimento_de_Especies_Florestais/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/andrerizzo/Reconhecimento_de_Especies_Florestais/zip/refs/heads/master [following]
# --2025-10-20 18:09:43--  https://codeload.github.com/andrerizzo/Reconhecimento_de_Especies_Florestais/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/content/Reconhecimento_de_Especies_Florestais.zip’
#
# /content/Reconhecim     [ <=>                ]  80.48K  --.-KB/s    in 0.05s
#
# ...

# %% [markdown]
# #### 1.3. Importação das Bibliotecas Necessárias

# %%
import warnings
warnings.filterwarnings('ignore')

from src.data_acquisition import *
from src.preprocess import *
from src.build_model import *
from src.train_model import *
from src.evaluate_model_v2 import evaluate_model
#from src.evaluate_model import training_eval, inference_performance_metrics
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Output()
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=695983ad-9de7-44ee-9e2e-f54719bd226c&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=6a3ee934159260134424f33b8ce1556cef8ddaf8ab35f2a637077e361877b58c
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as andrerizzo
# Initialized MLflow to track repo "andrerizzo/wood-species-recognition"
# Repository andrerizzo/wood-species-recognition initialized!
# Usando experimento existente: wood-species-experiments

# %% [markdown]
# #### 1.4. Definição das variáveis

# %%
# GOOGLE COLAB
UPLOAD_PATH = '/content'
PATH_DESTINO = '/content/images'
FILES_TO_DELETE_PATH = '/content/images/patches/class_9/0939*'
# Localização dos patches
IMAGES_PATH = '/content/images/patches'
#Localização dos patches já divididos em treino, validação e teste
train_path = '/content/images/train'
val_path = '/content/images/val'
test_path = '/content/images/test'


# MÁQUINA LOCAL
# Local onde os patches devem ser armazenados
#PATH_DESTINO = r'C:\Users\andre\teste'
# Localização dos patches a serem apagados
#FILES_TO_DELETE_PATH = r'C:\Users\andre\teste\patches\class_9\0939*'
# Localização dos patches
#IMAGES_PATH = r'C:\Users\andre\teste\patches'
#Localização dos patches já divididos em treino, validação e teste
#train_path = r'C:\Users\andre\teste\train'
#val_path = r'C:\Users\andre\teste\val'
#test_path = r'C:\Users\andre\teste\test'

# %% [markdown]
# ---
#
# <br>
#
# ### 2. Carregar Imagens

# %% [markdown]
# #### 2.1. Baixar os patches das imagens

# %%
ID_GOOGLE_IMAGES = ['1RajkAeTumEVBAbrq3BIVj8ELFm2USifw',
                    '1Sg0ZuRN5vRASb13mp5JVSkvRLeko_Mp8',
                    '1iPHhbOb7X8dc9c0PLj1uaw5PEmAUVrGh',
                    '1SHCsgrARnZIEZ43gauQf-8ycsk9OV3xy',
                    '18PW2ac7hGe494TAkGzg3IGEntktT6f9Q',
                    '1M9qKLrQ-Z98FTTW9Jo2xcpwjwSfHj3WN',
                    '1vGa8kdjsTlYQgM7mJzpteoKNE5IsGsz5']
n = 1
for id in ID_GOOGLE_IMAGES:
    zip_file = download_patches_file(id_google_drive_file=id,
                          path_destino=UPLOAD_PATH,
                          arquivo_destino=f'imagens{n}.zip'
                          )
    uncompress_patches(arquivo_zip=zip_file, path_destino=PATH_DESTINO)
    n=n+1
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1RajkAeTumEVBAbrq3BIVj8ELFm2USifw
# From (redirected): https://drive.google.com/uc?id=1RajkAeTumEVBAbrq3BIVj8ELFm2USifw&confirm=t&uuid=89382abd-7db9-4241-a424-2255125a44ec
# To: /content/imagens1.zip
# 100%|██████████| 967M/967M [00:10<00:00, 91.7MB/s]
#  Descompactando o arquivo /content/imagens1.zip ...
#
#  Descompactação finalizada
# Downloading...
# From (original): https://drive.google.com/uc?id=1Sg0ZuRN5vRASb13mp5JVSkvRLeko_Mp8
# From (redirected): https://drive.google.com/uc?id=1Sg0ZuRN5vRASb13mp5JVSkvRLeko_Mp8&confirm=t&uuid=c6669ef5-2c18-4b4a-9ec4-35ccb1e3bb87
# To: /content/imagens2.zip
# 100%|██████████| 953M/953M [00:08<00:00, 108MB/s]
#  Descompactando o arquivo /content/imagens2.zip ...
#
#  Descompactação finalizada
# Downloading...
# From (original): https://drive.google.com/uc?id=1iPHhbOb7X8dc9c0PLj1uaw5PEmAUVrGh
# ...

# %%
files_to_delete = glob.glob(FILES_TO_DELETE_PATH)

for file in files_to_delete:
    os.remove(file)
print(f'Arquivos deletados com sucesso !')
# Out:
# Arquivos deletados com sucesso !

# %% [markdown]
# #### 2.2. Gera lista das imagens existentes e respectivas classes

# %%
X_temp = gera_lista(image_path=IMAGES_PATH)

X = X_temp['imagem']
y = X_temp['classe']

# %% [markdown]
# #### 2.3. Gera lista de imagens que serão usadas para **treino**, **teste** e **validação**

# %%
X_train, X_test = train_test_val(image_ds=X, tam_teste=0.1,
                                 estratifica=y)
X_train, X_val = train_test_val(image_ds=X_train, tam_teste=0.2,
                                estratifica=y[X_train.index])

print(f'Número de imagens para treinamento: {len(X_train)}')
print(f'Número de imagens para validação: {len(X_val)}')
print(f'Número de imagens para teste: {len(X_test)}')
# Out:
# Número de imagens para treinamento: 2116
# Número de imagens para validação: 530
# Número de imagens para teste: 295

# %% [markdown]
# #### 2.4. Criação dos diretórios onde os symlinks serão armazenados

# %%
train_path, test_path, val_path =  folder_creation(root_patches_folder=PATH_DESTINO)
# Out:
# Diretórios de treinamento criados com sucesso !
#
# Diretórios de validação criados com sucesso !
#
# Diretórios de teste criados com sucesso !

# %% [markdown]
# #### 2.5. Criação dos symlinks

# %%
# Cria symlinks para imagens de treinamento
origem = IMAGES_PATH
destino = train_path
symlink(X_train, origem, destino)


# Cria symlinks para imagens de validação
origem =IMAGES_PATH
destino = val_path
symlink(X_val, origem, destino)


# Cria symlinks para imagens de teste
origem = IMAGES_PATH
destino = test_path
symlink(X_test, origem, destino)
# Out:
# ...
# Creating symlinks: 100%|██████████| 295/295 [00:00<00:00, 323.07it/s]

# %% [markdown]
# ---
#
# <br>
#
# ### 3. Pré-Processamento dos Dados

# %% [markdown]
# #### 3.1. Criação dos datasets de treino, validação e teste

# %%
train_ds = gera_dataset_train_test_val(train_path,
                                       classes='inferred',
                                       tipo_classes='categorical',
                                       tam_batch=32,
                                       tam_imagem=(224,224),
                                       aleatorio=True,
                                       percent_val=None,
                                       subconjunto=None,
                                       symlink=True
                                       )

val_ds = gera_dataset_train_test_val(val_path,
                                     classes='inferred',
                                     tipo_classes='categorical',
                                     tam_batch=32,
                                     tam_imagem=(224,224),
                                     aleatorio=False,
                                     percent_val=None,
                                     subconjunto=None,
                                     symlink=True
                                    )

test_ds = gera_dataset_train_test_val(test_path,
                                      classes='inferred',
                                      tipo_classes='categorical',
                                      tam_batch=32,
                                      tam_imagem=(224,224),
                                      aleatorio=False,
                                      percent_val=None,
                                      subconjunto=None,
                                      symlink=True
                                       )
# Out:
# Found 296240 files belonging to 41 classes.
# Found 74200 files belonging to 41 classes.
# Found 41300 files belonging to 41 classes.

# %%
train_class_names = train_ds.class_names
print("Train classes:", train_class_names)
# Out:
# Train classes: ['class_01', 'class_02', 'class_03', 'class_04', 'class_05', 'class_06', 'class_07', 'class_08', 'class_09', 'class_10', 'class_11', 'class_12', 'class_13', 'class_14', 'class_15', 'class_16', 'class_17', 'class_18', 'class_19', 'class_20', 'class_21', 'class_22', 'class_23', 'class_24', 'class_25', 'class_26', 'class_27', 'class_28', 'class_29', 'class_30', 'class_31', 'class_32', 'class_33', 'class_34', 'class_35', 'class_36', 'class_37', 'class_38', 'class_39', 'class_40', 'class_41']

# %% [markdown]
# #### 3.2. Normalização dos datasets

# %% [markdown]
# ##### 3.2.1 - MobileNetV2

# %%
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input as mobilenetv2_preprocess

train_images_norm = preprocess(dataset=train_ds,
                               preprocessing_fn=mobilenetv2_preprocess)

val_images_norm = preprocess(dataset=val_ds,
                             preprocessing_fn=mobilenetv2_preprocess)

test_images_norm = preprocess(dataset=test_ds,
                              preprocessing_fn=mobilenetv2_preprocess)

# %% [markdown]
# ##### 3.2.2 - MobileNetV3

# %%
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input as mobilenetv3_preprocess

train_images_norm = preprocess(dataset=train_ds,
                               preprocessing_fn=mobilenetv3_preprocess)

val_images_norm = preprocess(dataset=val_ds,
                             preprocessing_fn=mobilenetv3_preprocess)

test_images_norm = preprocess(dataset=test_ds,
                              preprocessing_fn=mobilenetv3_preprocess)

# %% [markdown]
# ##### 3.2.3 - EfficientNet

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess

train_images_norm = preprocess(dataset=train_ds,
                               preprocessing_fn=efficientnet_preprocess)

val_images_norm = preprocess(dataset=val_ds,
                             preprocessing_fn=efficientnet_preprocess)

test_images_norm = preprocess(dataset=test_ds,
                              preprocessing_fn=efficientnet_preprocess)

# %% [markdown]
# ---
#
# <br>
#
# ### 4. Modelo MobileNet v3 Large v1

# %% [markdown]
# #### 4.1. Criação e compilação do modelo MobileNetv3 Large v1

# %%
model_mobilenetv3_large_v1 = build_model_mobilenetv3_large_v1(formato_imagem=(224,224,3), num_classes=41)
model_mobilenetv3_large_v1 = compile_model_mobilenetv3(modelo=model_mobilenetv3_large_v1, lr_rate=0.0001)
model_mobilenetv3_large_v1.summary()
# Out:
# ...
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_2         │ (None, 224, 224,  │          0 │ input_layer_2[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_2[0][0] │
# │                     │ 16)               │            │                   │
# ...

# %% [markdown]
# #### 4.2. Treinamento do modelo MobileNetv3 Large v1

# %%
history_mobilenet_large_v1 = train_model(model=model_mobilenetv3_large_v1,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv3_large_v1_.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5327 - loss: 0.3443
# Epoch 1: val_accuracy improved from -inf to 0.84722, saving model to models/MobileNetv3_large_v1_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 183s 17ms/step - accuracy: 0.5327 - loss: 0.3443 - val_accuracy: 0.8472 - val_loss: 0.0800 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9254/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8146 - loss: 0.0959
# Epoch 2: val_accuracy improved from 0.84722 to 0.87310, saving model to models/MobileNetv3_large_v1_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 107s 12ms/step - accuracy: 0.8146 - loss: 0.0959 - val_accuracy: 0.8731 - val_loss: 0.0640 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9255/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8537 - loss: 0.0705
# Epoch 3: val_accuracy improved from 0.87310 to 0.88267, saving model to models/MobileNetv3_large_v1_.keras
# ...

# %% [markdown]
# #### 4.3. Avaliação do modelo MobileNetv3 Large v1

# %%
evaluate_model(
    model=model_mobilenetv3_large_v1,
    history=history_mobilenet_large_v1,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv3_large_v1",
    tags={"Modelo": "MobileNetV3-Large-v1",
          "Fine tuning": "Não",
          "Data treinamento": "20/09/2025",
          "Run date": "20/09/2025"}
)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=7, read=6, redirect=7, status=7)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /andrerizzo/wood-species-recognition.mlflow/api/2.0/mlflow/runs/create
# 🏃 View run mobilenetv3_large_v1 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/54033dec085c4e80876f85438523b9c5
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %% [markdown]
# ---
#
# <br>
#
# ### 5. Modelo MobileNet v3 Large v2

# %% [markdown]
# #### 5.1. Criação e compilação do modelo

# %%
model_mobilenetv3_large_v2 = build_model_mobilenetv3_large_v2(formato_imagem=(224,224,3), num_classes=41)
model_mobilenetv3_large_v2 = compile_model_mobilenetv3(modelo=model_mobilenetv3_large_v2, lr_rate=0.0001)
model_mobilenetv3_large_v2.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_5         │ (None, 224, 224,  │          0 │ input_layer_5[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_5[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# #### 5.2. Treinamento do modelo MobileNetv3 Large v2

# %%
history_mobilenetv3_large_v2 = train_model(model=model_mobilenetv3_large_v2,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv3_large_v2_.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7042 - loss: 0.2221
# Epoch 1: val_accuracy improved from -inf to 0.95784, saving model to models/MobileNetv3_large_v2_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 344s 30ms/step - accuracy: 0.7042 - loss: 0.2221 - val_accuracy: 0.9578 - val_loss: 0.0266 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9614 - loss: 0.0180
# Epoch 2: val_accuracy improved from 0.95784 to 0.96020, saving model to models/MobileNetv3_large_v2_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 231s 25ms/step - accuracy: 0.9614 - loss: 0.0180 - val_accuracy: 0.9602 - val_loss: 0.0259 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9257/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9771 - loss: 0.0101
# Epoch 3: val_accuracy improved from 0.96020 to 0.96307, saving model to models/MobileNetv3_large_v2_.keras
# ...

# %% [markdown]
# #### 5.3. Avaliação do modelo MobileNetv3 Large v2

# %%
evaluate_model(
    model=model_mobilenetv3_large_v2,
    history=history_mobilenetv3_large_v2,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv3_large_v2",
    tags={"Modelo": "MobileNetV3-Large-v2",
          "Fine tuning": "Sim - 20 camadas",
          "Data treinamento": "20/09/2025",
          "Run date": "20/09/2025"}
)
# Out:
# 🏃 View run mobilenetv3_large_v2 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/9fa1796e4a5e4e56ac1d43493d24b135
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %% [markdown]
# ---
#
# <br>
#
# ### 6. Modelo MobileNetv3 Small v2 - **Fine Tuning das 20 últimas camadas convolucionais**

# %% [markdown]
# #### 6.1. Criação e compilação do modelo

# %%
model_mobilenetv3_small_v2 = build_model_mobilenetv3_small_v2(formato_imagem=(224,224,3), num_classes=41)
model_mobilenetv3_small_v2 = compile_model_mobilenetv3(modelo=model_mobilenetv3_small_v2, lr_rate=0.0001)
model_mobilenetv3_small_v2.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_1[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# #### 6.2. Treinamento do modelo MobileNetv3 Large v2

# %%
history_mobilenetv3_small_v2 = train_model(model=model_mobilenetv3_small_v2,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv3_small_v2_.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6551 - loss: 0.2552
# Epoch 1: val_accuracy improved from -inf to 0.94832, saving model to models/MobileNetv3_small_v2_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 267s 23ms/step - accuracy: 0.6551 - loss: 0.2551 - val_accuracy: 0.9483 - val_loss: 0.0286 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9257/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9465 - loss: 0.0243
# Epoch 2: val_accuracy improved from 0.94832 to 0.95292, saving model to models/MobileNetv3_small_v2_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 158s 17ms/step - accuracy: 0.9465 - loss: 0.0243 - val_accuracy: 0.9529 - val_loss: 0.0268 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9255/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9659 - loss: 0.0138
# Epoch 3: val_accuracy improved from 0.95292 to 0.95972, saving model to models/MobileNetv3_small_v2_.keras
# ...

# %% [markdown]
# #### 6.3. Avaliação do modelo MobileNetv3 Small v2

# %%
evaluate_model(
    model=model_mobilenetv3_small_v2,
    history=history_mobilenetv3_small_v2,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv3_small_v2",
    tags={"Modelo": "MobileNetV3-Small-v2",
          "Fine tuning": "Sim - 20 últimas",
          "Data treinamento": "20/09/2025",
          "Run date": "20/09/2025"}
)
# Out:
# 🏃 View run mobilenetv3_small_v2 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/955201b509854e4eb38731c32b6bff37
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %% [markdown]
# ---
#
# <br>
#
# ### 7. Modelo MobileNetv3 Small v1 - **SEM Fine Tuning das Camadas Convolucionais**

# %% [markdown]
# #### 7.1. Criação e compilação do modelo

# %%
model_mobilenetv3_small_v1 = build_model_mobilenetv3_small_v1(formato_imagem=(224,224,3), num_classes=41)
model_mobilenetv3_small_v1 = compile_model_mobilenetv3(modelo=model_mobilenetv3_small_v1, lr_rate=0.0001)
model_mobilenetv3_small_v1.summary()
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_7         │ (None, 224, 224,  │          0 │ input_layer_9[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_7[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# #### 7.2. Treinamento do modelo MobileNetv3 Large v1

# %%
history_mobilenet_small_v1 = train_model(model=model_mobilenetv3_small_v1,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv3_small_v1_.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4998 - loss: 0.3673
# Epoch 1: val_accuracy improved from -inf to 0.82371, saving model to models/MobileNetv3_small_v1_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 115s 11ms/step - accuracy: 0.4998 - loss: 0.3673 - val_accuracy: 0.8237 - val_loss: 0.0946 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9251/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7870 - loss: 0.1111
# Epoch 2: val_accuracy improved from 0.82371 to 0.85305, saving model to models/MobileNetv3_small_v1_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 90s 10ms/step - accuracy: 0.7870 - loss: 0.1111 - val_accuracy: 0.8530 - val_loss: 0.0743 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9254/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8296 - loss: 0.0837
# Epoch 3: val_accuracy improved from 0.85305 to 0.86980, saving model to models/MobileNetv3_small_v1_.keras
# ...

# %% [markdown]
# #### 7.3. Avaliação do modelo MobileNetv3 Small v1

# %%
evaluate_model(
    model=model_mobilenetv3_small_v1,
    history=history_mobilenet_small_v1,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv3_small_v1",
    tags={"Modelo": "MobileNetV3-Small-v1",
          "Fine tuning": "Não",
          "Data treinamento": "20/09/2025",
          "Run date": "20/09/2025"}
)
# Out:
# 🏃 View run mobilenetv3_small_v1 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/22ee98153f4f4e388f0a4c91348ffa2a
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %%
# exportar history_mobilenet_small_v1 para um arquivo que possa ser carregado posteriormente junto com o modelo
import pickle

with open('history_mobilenet_small_v1.pkl', 'wb') as file:
    pickle.dump(history_mobilenet_small_v1.history, file)
    file.close()
    print('Arquivo salvo com sucesso !')
# Out:
# Arquivo salvo com sucesso !

# %%
import tensorflow as tf
from google.colab import drive
import pickle

drive.mount('/content/drive')

# Caminho do modelo salvo no Google Drive
gdrive_model_path = "/content/drive/MyDrive/USP/TCC/Application/models/MobileNetv3_small_v1.keras"
history_path = "/content/drive/MyDrive/USP/TCC/Application/models/history_mobilenet_small_v1.pkl"

# Carregar o modelo
model_mobilenetv3_small_v1 = tf.keras.models.load_model(gdrive_model_path)

# Carregar history
history_mobilenet_small_v1 = pickle.load(open(history_path, 'rb'))

# Conferir o summary
model_mobilenetv3_small_v1.summary()

# %% [markdown]
# ---
#
# <br>
#
# ### 8. Modelo MobileNetv2_v1 - **SEM Fine Tuning das Camadas Convolucionais**

# %% [markdown]
# #### 8.1. Criação e compilação do modelo

# %%
model_mobilenetv2_v1 = build_model_mobilenetV2_v1(formato_imagem=(224,224,3), num_classes=41)
model_mobilenetv2_v1 = compile_model_mobilenetv2(modelo=model_mobilenetv2_v1, lr_rate=0.0001)
model_mobilenetv2_v1.summary()
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 112, 112,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 112, 112,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ...

# %% [markdown]
# #### 8.2. Treinamento do modelo MobileNetv2_v1

# %%
history_mobilenetv2_v1 = train_model(model=model_mobilenetv2_v1,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv2_v1_.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4537 - loss: 0.4100
# Epoch 1: val_accuracy improved from -inf to 0.75160, saving model to models/MobileNetv2_v1_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 184s 17ms/step - accuracy: 0.4537 - loss: 0.4100 - val_accuracy: 0.7516 - val_loss: 0.1431 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9253/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7122 - loss: 0.1639
# Epoch 2: val_accuracy improved from 0.75160 to 0.78086, saving model to models/MobileNetv2_v1_.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 107s 12ms/step - accuracy: 0.7122 - loss: 0.1639 - val_accuracy: 0.7809 - val_loss: 0.1221 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9255/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7542 - loss: 0.1334
# Epoch 3: val_accuracy improved from 0.78086 to 0.79365, saving model to models/MobileNetv2_v1_.keras
# ...

# %% [markdown]
# #### 8.3. Avaliação do modelo MobileNetv2_v1

# %%
evaluate_model(
    model=model_mobilenetv2_v1,
    history=history_mobilenetv2_v1,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv2_v1",
    tags={"Modelo": "MobileNetV2-v1",
          "Fine tuning": "Não",
          "Data treinamento": "21/09/2025",
          "Run date": "21/09/2025"}
)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=6, connect=7, read=6, redirect=7, status=7)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /andrerizzo/wood-species-recognition.mlflow/api/2.0/mlflow/runs/create
# 🏃 View run mobilenetv2_v1 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/f9eb372a8cc942d1a9c40a95c83485ee
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %% [markdown]
# ---

# %% [markdown]
# ### 12. Modelo MobileNetV3 Small_v3 - Com número de camadas convolucionais variável

# %% [markdown]
# #### 12.1. Criação e compilação do modelo

# %%
model_mobilenetv3_small_v3 = build_model_mobilenetv3_small_v3(formato_imagem=(224,224,3), num_classes=41, trainable_layers=5)
model_mobilenetv3_small_v3 = compile_model_mobilenetv3(modelo=model_mobilenetv3_small_v3, lr_rate=0.0001)
model_mobilenetv3_small_v3.summary()

# %% [markdown]
# #### 12.2. Treinamento do modelo

# %%
history_mobilenet_small_v3 = train_model(model=model_mobilenetv3_small_v3,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv3_small_v3_CNN5.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )

# %% [markdown]
# #### 12.3. Avaliação do modelo

# %%
evaluate_model(
    model=model_mobilenetv3_small_v3,
    history=history_mobilenet_small_v3,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv3_small_v3",
    tags={"Modelo": "MobileNetV3-Small-v3",
          "Fine tuning": "Sim - 5 camadas",
          "Data treinamento": "20/10/2025",
          "Run date": "20/10/2025"}
)

# %% [markdown]
# ---

# %% [markdown]
# ### 13. Modelo MobileNetV3 Large_v3 - Com número de camadas convolucionais variável

# %% [markdown]
# #### 13.1. Criação e compilação do modelo

# %%
model_mobilenetv3_large_v3 = build_model_mobilenetv3_large_v3(formato_imagem=(224,224,3), num_classes=41, trainable_layers=5)
model_mobilenetv3_large_v3 = compile_model_mobilenetv3(modelo=model_mobilenetv3_large_v3, lr_rate=0.0001)
model_mobilenetv3_large_v3.summary()

# %% [markdown]
# #### 13.2. Treinamento do modelo

# %%
history_mobilenet_large_v3 = train_model(model=model_mobilenetv3_large_v3,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='MobileNetv3_large_v3_CNN5.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )

# %% [markdown]
# #### 13.3. Avaliação do modelo

# %%
evaluate_model(
    model=model_mobilenetv3_large_v3,
    history=history_mobilenet_large_v3,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="mobilenetv3_large_v3",
    tags={"Modelo": "MobileNetV3-Large-v3",
          "Fine tuning": "Sim - 5 camadas",
          "Data treinamento": "20/10/2025",
          "Run date": "20/10/2025"}
)

# %% [markdown]
# ---

# %% [markdown]
# <br>
#
# ## Família EfficientNet

# %% [markdown]
# ### 9. Modelo EfficientNet B0

# %% [markdown]
# #### 9.1. Criação e compilação

# %%
model_efficientnet_b0_v1 = build_model_efficientnet_b0(formato_imagem=(224,224,3), num_classes=41)
model_efficientnet_b0_v1 = compile_model_efficientnet(modelo=model_efficientnet_b0_v1, lr_rate=0.0001)
model_efficientnet_b0_v1.summary()
# Out:
# ...
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ...

# %% [markdown]
# #### 9.2. Treinamento

# %%
history_efficientnet_b0_v1 = train_model(model=model_efficientnet_b0_v1,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='EfficientNetB0_v1.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5077 - loss: 0.3610
# Epoch 1: val_accuracy improved from -inf to 0.83151, saving model to models/EfficientNetB0_v1.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 226s 20ms/step - accuracy: 0.5077 - loss: 0.3610 - val_accuracy: 0.8315 - val_loss: 0.0932 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9257/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7764 - loss: 0.1200
# Epoch 2: val_accuracy improved from 0.83151 to 0.85627, saving model to models/EfficientNetB0_v1.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 129s 14ms/step - accuracy: 0.7764 - loss: 0.1200 - val_accuracy: 0.8563 - val_loss: 0.0743 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9254/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8152 - loss: 0.0941
# Epoch 3: val_accuracy improved from 0.85627 to 0.86898, saving model to models/EfficientNetB0_v1.keras
# ...

# %% [markdown]
# #### 9.3. Avaliação

# %%
evaluate_model(
    model=model_efficientnet_b0_v1,
    history=history_efficientnet_b0_v1,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="efficientnet_b0_v1",
    tags={"Modelo": "EfficientNetB0-v1",
          "Fine tuning": "Não",
          "Data treinamento": "21/09/2025",
          "Run date": "21/09/2025"}
)
# Out:
# 🏃 View run efficientnet_b0_v1 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/c9d909a3ef7b499b99775c6f9db7a50c
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %% [markdown]
# ---
#
# <br>
#
# ### 10. Modelo EfficientNet B1

# %% [markdown]
# #### 10.1. Criação e compilação

# %%
model_efficientnet_b1_v1 = build_model_efficientnet_b1(formato_imagem=(224,224,3), num_classes=41)
model_efficientnet_b1_v1 = compile_model_efficientnet(modelo=model_efficientnet_b1_v1, lr_rate=0.0001)
model_efficientnet_b1_v1.summary()
# Out:
# ...
# 27018416/27018416 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 224, 224,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ...

# %% [markdown]
# #### 10.2. Treinamento

# %%
history_efficientnet_b1_v1 = train_model(model=model_efficientnet_b1_v1,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='EfficientNetB1_v1.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5399 - loss: 0.3340
# Epoch 1: val_accuracy improved from -inf to 0.83535, saving model to models/EfficientNetB1_v1.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 307s 27ms/step - accuracy: 0.5399 - loss: 0.3340 - val_accuracy: 0.8354 - val_loss: 0.0852 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9256/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7986 - loss: 0.1062
# Epoch 2: val_accuracy improved from 0.83535 to 0.86019, saving model to models/EfficientNetB1_v1.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 174s 19ms/step - accuracy: 0.7986 - loss: 0.1062 - val_accuracy: 0.8602 - val_loss: 0.0690 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9256/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8334 - loss: 0.0835
# Epoch 3: val_accuracy improved from 0.86019 to 0.87067, saving model to models/EfficientNetB1_v1.keras
# ...

# %% [markdown]
# #### 10.3. Avaliação

# %%
evaluate_model(
    model=model_efficientnet_b1_v1,
    history=history_efficientnet_b1_v1,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="efficientnet_b1_v1",
    tags={"Modelo": "EfficientNetB1-v1",
          "Fine tuning": "Não",
          "Data treinamento": "20/10/2025",
          "Run date": "20/10/2025"}
)
# Out:
# 🏃 View run efficientnet_b1_v1 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/a1467b644d5c4024af8509a1c828b90b
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0

# %% [markdown]
# ---

# %% [markdown]
# <br>
#
# ### 11. Modelo EfficientNetV2 B0

# %% [markdown]
# #### 11.1. Criação e compilação

# %%
model_efficientnetV2_b0_v1 = build_model_efficientnetv2_b0(formato_imagem=(224,224,3), num_classes=41)
model_efficientnetV2_b0_v1 = compile_model_efficientnet(modelo=model_efficientnetV2_b0_v1, lr_rate=0.0001)
model_efficientnetV2_b0_v1.summary()
# Out:
# ...
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_2         │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_1     │ (None, 224, 224,  │          0 │ rescaling_2[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ...

# %% [markdown]
# #### 11.2. Treinamento

# %%
history_efficientnetV2_b0_v1 = train_model(model=model_efficientnetV2_b0_v1,
                      train_images=train_images_norm,
                      val_images=val_images_norm,
                      output_dir='models',
                      model_file_name='EfficientNetV2_b0_v1.keras',
                      epochs=40,
                      patience=5,
                      min_lr_ROP=0.00001,
                      factorROP=0.5,
                      patienceROP=3
                      )
# Out:
# Epoch 1/40
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5457 - loss: 0.3313
# Epoch 1: val_accuracy improved from -inf to 0.84543, saving model to models/EfficientNetV2_b0_v1.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 203s 18ms/step - accuracy: 0.5457 - loss: 0.3313 - val_accuracy: 0.8454 - val_loss: 0.0813 - learning_rate: 1.0000e-04
# Epoch 2/40
# 9256/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8086 - loss: 0.1000
# Epoch 2: val_accuracy improved from 0.84543 to 0.87663, saving model to models/EfficientNetV2_b0_v1.keras
# 9258/9258 ━━━━━━━━━━━━━━━━━━━━ 133s 14ms/step - accuracy: 0.8086 - loss: 0.1000 - val_accuracy: 0.8766 - val_loss: 0.0608 - learning_rate: 1.0000e-04
# Epoch 3/40
# 9255/9258 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8456 - loss: 0.0766
# Epoch 3: val_accuracy improved from 0.87663 to 0.88871, saving model to models/EfficientNetV2_b0_v1.keras
# ...

# %% [markdown]
# #### 11.3. Avaliação

# %%
evaluate_model(
    model=model_efficientnetV2_b0_v1,
    history=history_efficientnetV2_b0_v1,
    test_dataset=test_images_norm,
    class_names=train_class_names,
    run_name="efficientnetV2_b0_v1",
    tags={"Modelo": "EfficientNetV2_b0_v1",
          "Fine tuning": "Não",
          "Data treinamento": "21/09/2025",
          "Run date": "21/09/2025"}
)
# Out:
# 🏃 View run efficientnetV2_b0_v1 at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0/runs/f41f7bd9caa94fc4b0278040c7895a96
# 🧪 View experiment at: https://dagshub.com/andrerizzo/wood-species-recognition.mlflow/#/experiments/0
